# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd

# %%
A=pd.read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/train.csv")

# %%
A
# Out:
#     id Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura        Integra    Small       12.9   15.9       18.8
# 1    2        Acura         Legend  Midsize       29.2   33.9       38.7
# 2    3         Audi             90  Compact       25.9   29.1       32.3
# 3    4         Audi            100  Midsize       30.8   37.7       44.6
# 4    5          BMW           535i  Midsize       23.7   30.0       36.2
# ..  ..          ...            ...      ...        ...    ...        ...
# 65  66       Nissan          Quest      Van       16.7   19.1       21.5
# 66  67       Nissan         Maxima  Midsize       21.0   21.5       22.0
# 67  68   Oldsmobile        Achieva  Compact       13.0   13.5       14.0
# 68  69   Oldsmobile  Cutlass_Ciera  Midsize       14.2   16.3       18.4
# 69  70   Oldsmobile     Silhouette      Van       19.5   19.5       19.5
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
A.isna().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               4
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        2
# Luggage.room          9
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
from Wd8pm import replacer

# %%
replacer(A)

# %%
A.isna().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
from Wd8pm import OL
q = OL(A)

# %%
q
# Out:
# [16, 30, 38, 41, 58, 59]

# %%
A = A.drop(index=q,axis=0)

# %%
A.shape
# Out:
# (64, 28)

# %%
A.index = range(0,64)

# %%
A
# Out:
#     id Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura        Integra    Small       12.9   15.9       18.8
# 1    2        Acura         Legend  Midsize       29.2   33.9       38.7
# 2    3         Audi             90  Compact       25.9   29.1       32.3
# 3    4         Audi            100  Midsize       30.8   37.7       44.6
# 4    5          BMW           535i  Midsize       23.7   30.0       36.2
# ..  ..          ...            ...      ...        ...    ...        ...
# 59  66       Nissan          Quest      Van       16.7   19.1       21.5
# 60  67       Nissan         Maxima  Midsize       21.0   21.5       22.0
# 61  68   Oldsmobile        Achieva  Compact       13.0   13.5       14.0
# 62  69   Oldsmobile  Cutlass_Ciera  Midsize       14.2   16.3       18.4
# 63  70   Oldsmobile     Silhouette      Van       19.5   19.5       19.5
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %% [markdown]
# # EDA

# %%
X=A.drop(labels=["id","Make","Model","Weight"],axis=1)
Y=A[["Weight"]]

# %%
from Wd8pm import preprocessing
Xnew = preprocessing(X)
Xnew
# Out:
#     Min.Price     Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0   -0.586112 -0.481700  -0.380045  0.927439     0.718667   -0.999895
# 1    1.230383  1.481223   1.673522 -0.833123    -0.806019    0.325410
# 2    0.862626  0.957777   1.013078 -0.330105    -0.551905   -0.053249
# 3    1.408689  1.895617   2.282369 -0.581614    -0.551905   -0.053249
# 4    0.617455  1.055923   1.415536  0.172912     0.464553    0.609403
# ..        ...       ...        ...       ...          ...         ...
# 59  -0.162635 -0.132736  -0.101421 -1.084632    -1.314248    0.136080
# 60   0.316563  0.128987  -0.049824 -0.078597    -0.551905    0.136080
# 61  -0.574968 -0.743423  -0.875378  0.675930     0.718667   -0.526572
# 62  -0.441238 -0.438079  -0.421323  0.424421     0.718667   -0.621237
# 63   0.149401 -0.089115  -0.307809 -0.833123    -1.314248    0.893397
#
#     Horsepower       RPM  Rev.per.mile  Fuel.tank.capacity  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=41)

# %%
from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     70.25
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):            0.00235
# Time:                        20:53:47   Log-Likelihood:                -211.24
# No. Observations:                  51   AIC:                             518.5
# Df Residuals:                       3   BIC:                             611.2
# Df Model:                          47
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
ol.pvalues.sort_values()
# Out:
# const                      0.000133
# AirBags_Driver only        0.004724
# AirBags_None               0.012986
# Man.trans.avail_Yes        0.014055
# Origin_USA                 0.018221
#                              ...
# Manufacturer_Oldsmobile    0.909160
# Manufacturer_Nissan        0.936046
# Manufacturer_Acura         0.944541
# Type_Small                 0.956847
# RPM                        0.985711
# Length: 61, dtype: float64

# %%
Xnew=Xnew.drop(labels=["RPM"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     95.68
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           0.000225
# Time:                        20:53:47   Log-Likelihood:                -211.24
# No. Observations:                  51   AIC:                             516.5
# Df Residuals:                       4   BIC:                             607.3
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         0.000006
# AirBags_Driver only           0.000219
# Man.trans.avail_Yes           0.001483
# AirBags_None                  0.002767
# Origin_USA                    0.005180
# MPG.highway                   0.005674
# Cylinders_4                   0.009049
# Man.trans.avail_No            0.009362
# Cylinders_6                   0.013224
# DriveTrain_Front              0.023181
# Origin_non-USA                0.024030
# Rear.seat.room                0.033736
# DriveTrain_Rear               0.037319
# Horsepower                    0.038076
# Luggage.room                  0.051681
# AirBags_Driver & Passenger    0.054305
# Manufacturer_Chrylser         0.055643
# Wheelbase                     0.071743
# Manufacturer_Cadillac         0.076459
# Type_Van                      0.106678
# Manufacturer_Chrysler         0.190730
# Manufacturer_Buick            0.213461
# Fuel.tank.capacity            0.215231
# Manufacturer_Mazda            0.221056
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Acura"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     95.68
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           0.000225
# Time:                        20:53:47   Log-Likelihood:                -211.24
# No. Observations:                  51   AIC:                             516.5
# Df Residuals:                       4   BIC:                             607.3
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         0.000004
# AirBags_Driver only           0.000342
# Origin_USA                    0.001794
# Man.trans.avail_Yes           0.001908
# AirBags_None                  0.003071
# MPG.highway                   0.005674
# Man.trans.avail_No            0.007615
# Origin_non-USA                0.008562
# Cylinders_4                   0.009466
# Cylinders_6                   0.014445
# DriveTrain_Front              0.019702
# Rear.seat.room                0.033736
# Horsepower                    0.038076
# DriveTrain_Rear               0.040588
# AirBags_Driver & Passenger    0.048641
# Luggage.room                  0.051681
# Manufacturer_Chrylser         0.053065
# Wheelbase                     0.071743
# Manufacturer_Cadillac         0.072853
# Type_Van                      0.107068
# Manufacturer_Mazda            0.145346
# Manufacturer_Chrysler         0.186796
# Fuel.tank.capacity            0.215231
# MPG.city                      0.222421
# ...

# %%
Xnew=Xnew.drop(labels=["Type_Small"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     95.68
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           0.000225
# Time:                        20:53:47   Log-Likelihood:                -211.24
# No. Observations:                  51   AIC:                             516.5
# Df Residuals:                       4   BIC:                             607.3
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         0.000159
# AirBags_Driver only           0.000172
# Man.trans.avail_Yes           0.000379
# Origin_USA                    0.000447
# AirBags_None                  0.001595
# MPG.highway                   0.005674
# Cylinders_4                   0.009955
# Cylinders_6                   0.013532
# Origin_non-USA                0.020940
# Man.trans.avail_No            0.021076
# DriveTrain_Rear               0.028223
# DriveTrain_Front              0.032338
# Rear.seat.room                0.033736
# Horsepower                    0.038076
# Manufacturer_Chrylser         0.050628
# Luggage.room                  0.051681
# Manufacturer_Cadillac         0.070847
# Wheelbase                     0.071743
# AirBags_Driver & Passenger    0.078504
# Manufacturer_Mazda            0.145346
# Manufacturer_Chrysler         0.181081
# Fuel.tank.capacity            0.215231
# MPG.city                      0.222421
# Manufacturer_Buick            0.235679
# ...

# %%
Xnew=Xnew.drop(labels=["Type_Sporty"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     122.1
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.93e-05
# Time:                        20:53:47   Log-Likelihood:                -211.28
# No. Observations:                  51   AIC:                             514.6
# Df Residuals:                       5   BIC:                             603.4
# Df Model:                          45
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         0.000005
# AirBags_Driver only           0.000019
# Man.trans.avail_Yes           0.000033
# Origin_USA                    0.000033
# AirBags_None                  0.000312
# MPG.highway                   0.001796
# Origin_non-USA                0.002507
# Man.trans.avail_No            0.002712
# Cylinders_4                   0.003324
# Cylinders_6                   0.005277
# DriveTrain_Rear               0.006263
# DriveTrain_Front              0.007087
# Horsepower                    0.007438
# Rear.seat.room                0.010579
# Luggage.room                  0.018156
# Manufacturer_Chrylser         0.020592
# AirBags_Driver & Passenger    0.023761
# Wheelbase                     0.035666
# Manufacturer_Cadillac         0.036531
# Manufacturer_Mazda            0.069735
# Fuel.tank.capacity            0.102463
# Manufacturer_Chrysler         0.109423
# MPG.city                      0.138501
# Passengers                    0.138966
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Nissan"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     148.8
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.53e-06
# Time:                        20:53:48   Log-Likelihood:                -211.45
# No. Observations:                  51   AIC:                             512.9
# Df Residuals:                       6   BIC:                             599.8
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         4.424774e-07
# Origin_USA                    7.559959e-07
# AirBags_Driver only           1.940480e-06
# Man.trans.avail_Yes           4.322908e-06
# AirBags_None                  3.888683e-05
# Origin_non-USA                4.102050e-04
# MPG.highway                   5.437361e-04
# Cylinders_4                   8.027526e-04
# Man.trans.avail_No            8.034648e-04
# Cylinders_6                   1.404418e-03
# DriveTrain_Rear               2.592718e-03
# Rear.seat.room                2.688683e-03
# DriveTrain_Front              3.008576e-03
# Horsepower                    3.196582e-03
# Wheelbase                     9.013973e-03
# Luggage.room                  9.181496e-03
# Manufacturer_Chrylser         9.676161e-03
# AirBags_Driver & Passenger    1.042215e-02
# Manufacturer_Cadillac         1.505122e-02
# Manufacturer_Mazda            1.793959e-02
# Manufacturer_Chrysler         6.023128e-02
# Fuel.tank.capacity            6.133293e-02
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Oldsmobile"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     148.8
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.53e-06
# Time:                        20:53:48   Log-Likelihood:                -211.45
# No. Observations:                  51   AIC:                             512.9
# Df Residuals:                       6   BIC:                             599.8
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         3.668893e-07
# AirBags_Driver only           2.526372e-06
# Man.trans.avail_Yes           6.822979e-06
# Origin_USA                    3.423557e-05
# AirBags_None                  3.952498e-05
# MPG.highway                   5.437361e-04
# Man.trans.avail_No            6.697237e-04
# Cylinders_4                   7.460482e-04
# Origin_non-USA                1.106353e-03
# Cylinders_6                   1.347750e-03
# Rear.seat.room                2.688683e-03
# DriveTrain_Front              2.746257e-03
# DriveTrain_Rear               2.774634e-03
# Horsepower                    3.196582e-03
# Wheelbase                     9.013973e-03
# Luggage.room                  9.181496e-03
# AirBags_Driver & Passenger    9.683932e-03
# Manufacturer_Chrylser         1.614321e-02
# Manufacturer_Mazda            1.793959e-02
# Manufacturer_Cadillac         2.653996e-02
# Fuel.tank.capacity            6.133293e-02
# MPG.city                      8.168812e-02
# ...

# %%
Xnew=Xnew.drop(labels=["Cylinders_rotary"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     148.8
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.53e-06
# Time:                        20:53:48   Log-Likelihood:                -211.45
# No. Observations:                  51   AIC:                             512.9
# Df Residuals:                       6   BIC:                             599.8
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# AirBags_Driver only           0.000027
# const                         0.000034
# Man.trans.avail_Yes           0.000105
# Origin_USA                    0.000195
# AirBags_None                  0.000257
# MPG.highway                   0.000544
# Man.trans.avail_No            0.000851
# Origin_non-USA                0.001398
# DriveTrain_Front              0.002420
# Rear.seat.room                0.002689
# DriveTrain_Rear               0.002707
# Horsepower                    0.003197
# Wheelbase                     0.009014
# Luggage.room                  0.009181
# AirBags_Driver & Passenger    0.010035
# Manufacturer_Chrylser         0.016143
# Manufacturer_Mazda            0.017940
# Manufacturer_Cadillac         0.026540
# Fuel.tank.capacity            0.061333
# MPG.city                      0.081688
# Manufacturer_Chrysler         0.099207
# Passengers                    0.101637
# Manufacturer_Hyundai          0.117761
# Rev.per.mile                  0.143193
# ...

# %%
Xnew=Xnew.drop(labels=["Cylinders_8"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     177.7
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.10e-07
# Time:                        20:53:48   Log-Likelihood:                -211.45
# No. Observations:                  51   AIC:                             510.9
# Df Residuals:                       7   BIC:                             595.9
# Df Model:                          43
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# AirBags_Driver only           1.661827e-07
# Man.trans.avail_Yes           1.796198e-07
# const                         2.396297e-07
# Origin_USA                    2.299275e-06
# AirBags_None                  7.505010e-06
# MPG.highway                   1.744387e-04
# Man.trans.avail_No            2.485768e-04
# Origin_non-USA                4.511294e-04
# DriveTrain_Rear               8.324884e-04
# Rear.seat.room                9.715338e-04
# DriveTrain_Front              9.926913e-04
# Horsepower                    1.162300e-03
# Luggage.room                  1.964954e-03
# Wheelbase                     4.563138e-03
# AirBags_Driver & Passenger    4.795428e-03
# Cylinders_6                   6.920222e-03
# Manufacturer_Chrylser         8.716888e-03
# Cylinders_4                   9.031340e-03
# Manufacturer_Mazda            9.999122e-03
# Manufacturer_Cadillac         1.456671e-02
# Fuel.tank.capacity            2.394853e-02
# Passengers                    5.581529e-02
# ...

# %%
Xnew=Xnew.drop(labels=["Width"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     198.9
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           8.77e-09
# Time:                        20:53:48   Log-Likelihood:                -212.58
# No. Observations:                  51   AIC:                             511.2
# Df Residuals:                       8   BIC:                             594.2
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.221892e-08
# Man.trans.avail_Yes           1.682238e-08
# AirBags_Driver only           2.269295e-08
# Origin_USA                    3.330804e-07
# AirBags_None                  6.050440e-07
# Man.trans.avail_No            2.011874e-05
# Origin_non-USA                4.256303e-05
# MPG.highway                   5.412347e-05
# Horsepower                    9.570450e-05
# DriveTrain_Rear               2.745523e-04
# Rear.seat.room                2.923954e-04
# DriveTrain_Front              3.915309e-04
# Luggage.room                  8.261732e-04
# AirBags_Driver & Passenger    2.272675e-03
# Wheelbase                     2.522237e-03
# Manufacturer_Mazda            4.143462e-03
# Cylinders_6                   4.503067e-03
# Manufacturer_Chrylser         5.781189e-03
# Cylinders_4                   6.095662e-03
# Manufacturer_Cadillac         8.712376e-03
# Fuel.tank.capacity            1.707290e-02
# DriveTrain_4WD                2.961362e-02
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Lexus"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     221.3
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           6.55e-10
# Time:                        20:53:48   Log-Likelihood:                -213.47
# No. Observations:                  51   AIC:                             510.9
# Df Residuals:                       9   BIC:                             592.1
# Df Model:                          41
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.171556e-10
# Man.trans.avail_Yes           9.162158e-10
# AirBags_Driver only           2.315784e-09
# Origin_USA                    2.803086e-08
# Man.trans.avail_No            5.462268e-08
# AirBags_None                  1.296707e-07
# Origin_non-USA                1.669231e-07
# DriveTrain_Rear               2.228019e-06
# Horsepower                    3.926534e-06
# DriveTrain_Front              7.174363e-06
# MPG.highway                   1.881080e-05
# Rear.seat.room                3.031994e-05
# AirBags_Driver & Passenger    6.925102e-05
# Luggage.room                  4.378953e-04
# Manufacturer_BMW              7.876360e-04
# Wheelbase                     9.379379e-04
# Cylinders_6                   1.035154e-03
# DriveTrain_4WD                1.634920e-03
# Manufacturer_Mazda            2.067964e-03
# Fuel.tank.capacity            3.489633e-03
# Cylinders_4                   3.681275e-03
# Manufacturer_Chrylser         3.916257e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Geo"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     221.3
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           6.55e-10
# Time:                        20:53:48   Log-Likelihood:                -213.47
# No. Observations:                  51   AIC:                             510.9
# Df Residuals:                       9   BIC:                             592.1
# Df Model:                          41
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.171556e-10
# Man.trans.avail_Yes           9.162158e-10
# AirBags_Driver only           2.315784e-09
# Origin_USA                    2.803086e-08
# Man.trans.avail_No            5.462268e-08
# AirBags_None                  1.296707e-07
# Origin_non-USA                1.669231e-07
# DriveTrain_Rear               2.228019e-06
# Horsepower                    3.926534e-06
# DriveTrain_Front              7.174363e-06
# MPG.highway                   1.881080e-05
# Rear.seat.room                3.031994e-05
# AirBags_Driver & Passenger    6.925102e-05
# Luggage.room                  4.378953e-04
# Manufacturer_BMW              7.876360e-04
# Wheelbase                     9.379379e-04
# Cylinders_6                   1.035154e-03
# DriveTrain_4WD                1.634920e-03
# Manufacturer_Mazda            2.067964e-03
# Fuel.tank.capacity            3.489633e-03
# Cylinders_4                   3.681275e-03
# Manufacturer_Chrylser         3.916257e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Min.Price"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     246.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           4.50e-11
# Time:                        20:53:48   Log-Likelihood:                -214.07
# No. Observations:                  51   AIC:                             510.1
# Df Residuals:                      10   BIC:                             589.4
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.035810e-11
# Man.trans.avail_Yes           4.903204e-11
# AirBags_Driver only           2.942486e-10
# Origin_USA                    4.992882e-09
# AirBags_None                  9.507059e-09
# Man.trans.avail_No            9.897923e-09
# Origin_non-USA                2.889230e-08
# DriveTrain_Rear               5.345219e-07
# Horsepower                    1.221021e-06
# DriveTrain_Front              2.339673e-06
# MPG.highway                   6.099371e-06
# Rear.seat.room                6.156355e-06
# AirBags_Driver & Passenger    2.738008e-05
# Luggage.room                  2.284908e-04
# Manufacturer_BMW              3.015839e-04
# Wheelbase                     4.623744e-04
# Cylinders_6                   5.548128e-04
# DriveTrain_4WD                9.832285e-04
# Manufacturer_Mazda            1.279216e-03
# Manufacturer_Chrylser         1.754076e-03
# Fuel.tank.capacity            2.043318e-03
# Cylinders_4                   2.350629e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Mercury"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     246.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           4.50e-11
# Time:                        20:53:48   Log-Likelihood:                -214.07
# No. Observations:                  51   AIC:                             510.1
# Df Residuals:                      10   BIC:                             589.4
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.035810e-11
# Man.trans.avail_Yes           4.903204e-11
# AirBags_Driver only           2.942486e-10
# Origin_USA                    4.992882e-09
# AirBags_None                  9.507059e-09
# Man.trans.avail_No            9.897923e-09
# Origin_non-USA                2.889230e-08
# DriveTrain_Rear               5.345219e-07
# Horsepower                    1.221021e-06
# DriveTrain_Front              2.339673e-06
# MPG.highway                   6.099371e-06
# Rear.seat.room                6.156355e-06
# AirBags_Driver & Passenger    2.738008e-05
# Luggage.room                  2.284908e-04
# Manufacturer_BMW              3.015839e-04
# Wheelbase                     4.623744e-04
# Cylinders_6                   5.548128e-04
# DriveTrain_4WD                9.832285e-04
# Manufacturer_Mazda            1.279216e-03
# Manufacturer_Chrylser         1.754076e-03
# Fuel.tank.capacity            2.043318e-03
# Cylinders_4                   2.350629e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Turn.circle"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     270.6
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           3.02e-12
# Time:                        20:53:48   Log-Likelihood:                -214.73
# No. Observations:                  51   AIC:                             509.5
# Df Residuals:                      11   BIC:                             586.7
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         2.096613e-13
# Man.trans.avail_Yes           5.257398e-12
# AirBags_Driver only           3.140514e-11
# Man.trans.avail_No            4.652251e-10
# Origin_non-USA                6.836337e-10
# Origin_USA                    9.072022e-10
# AirBags_None                  1.787398e-09
# DriveTrain_Rear               1.127458e-07
# Horsepower                    1.706637e-07
# DriveTrain_Front              1.808753e-07
# AirBags_Driver & Passenger    1.926000e-06
# Rear.seat.room                2.054346e-06
# MPG.highway                   2.100088e-06
# Manufacturer_BMW              6.044744e-05
# Luggage.room                  1.241257e-04
# Cylinders_6                   2.258946e-04
# Wheelbase                     2.566749e-04
# DriveTrain_4WD                4.445860e-04
# Manufacturer_Mazda            7.519542e-04
# Fuel.tank.capacity            9.910906e-04
# Manufacturer_Chrylser         1.161853e-03
# Cylinders_4                   1.420200e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Infiniti"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     270.6
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           3.02e-12
# Time:                        20:53:48   Log-Likelihood:                -214.73
# No. Observations:                  51   AIC:                             509.5
# Df Residuals:                      11   BIC:                             586.7
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         2.096613e-13
# Man.trans.avail_Yes           5.257398e-12
# AirBags_Driver only           3.140514e-11
# Man.trans.avail_No            4.652251e-10
# Origin_non-USA                6.836337e-10
# Origin_USA                    9.072022e-10
# AirBags_None                  1.787398e-09
# DriveTrain_Rear               1.127458e-07
# Horsepower                    1.706637e-07
# DriveTrain_Front              1.808753e-07
# AirBags_Driver & Passenger    1.926000e-06
# Rear.seat.room                2.054346e-06
# MPG.highway                   2.100088e-06
# Manufacturer_BMW              6.044744e-05
# Luggage.room                  1.241257e-04
# Cylinders_6                   2.258946e-04
# Wheelbase                     2.566749e-04
# DriveTrain_4WD                4.445860e-04
# Manufacturer_Mazda            7.519542e-04
# Fuel.tank.capacity            9.910906e-04
# Manufacturer_Chrylser         1.161853e-03
# Cylinders_4                   1.420200e-03
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Dodge"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     298.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.86e-13
# Time:                        20:53:48   Log-Likelihood:                -215.14
# No. Observations:                  51   AIC:                             508.3
# Df Residuals:                      12   BIC:                             583.6
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         9.907157e-15
# Man.trans.avail_Yes           2.285118e-13
# Origin_USA                    2.673980e-13
# AirBags_Driver only           1.640971e-12
# Origin_non-USA                6.261643e-12
# Man.trans.avail_No            7.939055e-11
# AirBags_None                  3.279543e-10
# DriveTrain_Rear               2.033463e-08
# Horsepower                    4.950429e-08
# DriveTrain_Front              5.195175e-08
# MPG.highway                   5.182970e-07
# AirBags_Driver & Passenger    6.750962e-07
# Rear.seat.room                7.483296e-07
# Manufacturer_BMW              2.950109e-05
# Luggage.room                  5.057984e-05
# Cylinders_6                   9.458405e-05
# Wheelbase                     1.384318e-04
# Manufacturer_Mazda            2.253256e-04
# DriveTrain_4WD                2.415059e-04
# Manufacturer_Chrylser         3.253295e-04
# Cylinders_4                   4.159849e-04
# Fuel.tank.capacity            5.491513e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Ford"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     329.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           1.04e-14
# Time:                        20:53:49   Log-Likelihood:                -215.34
# No. Observations:                  51   AIC:                             506.7
# Df Residuals:                      13   BIC:                             580.1
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         7.589923e-16
# Man.trans.avail_Yes           9.661627e-15
# Origin_USA                    1.936466e-14
# AirBags_Driver only           1.890613e-13
# Origin_non-USA                5.357647e-13
# Man.trans.avail_No            6.437417e-12
# AirBags_None                  1.017434e-11
# DriveTrain_Rear               1.235134e-09
# Horsepower                    1.069783e-08
# DriveTrain_Front              1.189435e-08
# AirBags_Driver & Passenger    6.528541e-08
# MPG.highway                   1.638323e-07
# Rear.seat.room                2.142247e-07
# Manufacturer_BMW              7.413011e-06
# Luggage.room                  2.520406e-05
# Cylinders_6                   3.966293e-05
# Wheelbase                     4.926705e-05
# DriveTrain_4WD                7.807682e-05
# Manufacturer_Mazda            1.253470e-04
# Cylinders_4                   1.370524e-04
# Fuel.tank.capacity            1.517682e-04
# Manufacturer_Chrylser         1.769709e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Type_Large"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     357.7
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           6.06e-16
# Time:                        20:53:49   Log-Likelihood:                -215.81
# No. Observations:                  51   AIC:                             505.6
# Df Residuals:                      14   BIC:                             577.1
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.880462e-18
# Origin_USA                    2.876140e-16
# Man.trans.avail_Yes           6.002426e-16
# AirBags_Driver only           3.049057e-15
# Origin_non-USA                2.452228e-14
# Man.trans.avail_No            1.375730e-13
# AirBags_None                  1.060221e-12
# DriveTrain_Rear               2.825837e-10
# DriveTrain_Front              2.063564e-09
# Horsepower                    2.775335e-09
# AirBags_Driver & Passenger    1.890744e-08
# MPG.highway                   2.584230e-08
# Rear.seat.room                6.129111e-08
# Manufacturer_BMW              2.364736e-06
# Luggage.room                  1.355947e-05
# Cylinders_6                   2.160722e-05
# Wheelbase                     2.655433e-05
# DriveTrain_4WD                3.943324e-05
# Fuel.tank.capacity            4.477559e-05
# Manufacturer_Mazda            5.259198e-05
# Cylinders_4                   8.319975e-05
# Manufacturer_Chrylser         1.054720e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Honda"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     357.7
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           6.06e-16
# Time:                        20:53:49   Log-Likelihood:                -215.81
# No. Observations:                  51   AIC:                             505.6
# Df Residuals:                      14   BIC:                             577.1
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.880462e-18
# Origin_USA                    2.876140e-16
# Man.trans.avail_Yes           6.002426e-16
# AirBags_Driver only           3.049057e-15
# Origin_non-USA                2.452228e-14
# Man.trans.avail_No            1.375730e-13
# AirBags_None                  1.060221e-12
# DriveTrain_Rear               2.825837e-10
# DriveTrain_Front              2.063564e-09
# Horsepower                    2.775335e-09
# AirBags_Driver & Passenger    1.890744e-08
# MPG.highway                   2.584230e-08
# Rear.seat.room                6.129111e-08
# Manufacturer_BMW              2.364736e-06
# Luggage.room                  1.355947e-05
# Cylinders_6                   2.160722e-05
# Wheelbase                     2.655433e-05
# DriveTrain_4WD                3.943324e-05
# Fuel.tank.capacity            4.477559e-05
# Manufacturer_Mazda            5.259198e-05
# Cylinders_4                   8.319975e-05
# Manufacturer_Chrylser         1.054720e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Mitsubishi"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     357.7
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           6.06e-16
# Time:                        20:53:49   Log-Likelihood:                -215.81
# No. Observations:                  51   AIC:                             505.6
# Df Residuals:                      14   BIC:                             577.1
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.880462e-18
# Origin_USA                    2.876140e-16
# Man.trans.avail_Yes           6.002426e-16
# AirBags_Driver only           3.049057e-15
# Origin_non-USA                2.452228e-14
# Man.trans.avail_No            1.375730e-13
# AirBags_None                  1.060221e-12
# DriveTrain_Rear               2.825837e-10
# DriveTrain_Front              2.063564e-09
# Horsepower                    2.775335e-09
# AirBags_Driver & Passenger    1.890744e-08
# MPG.highway                   2.584230e-08
# Rear.seat.room                6.129111e-08
# Manufacturer_BMW              2.364736e-06
# Luggage.room                  1.355947e-05
# Cylinders_6                   2.160722e-05
# Wheelbase                     2.655433e-05
# DriveTrain_4WD                3.943324e-05
# Fuel.tank.capacity            4.477559e-05
# Manufacturer_Mazda            5.259198e-05
# Cylinders_4                   8.319975e-05
# Manufacturer_Chrylser         1.054720e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Type_Compact"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     362.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           5.62e-17
# Time:                        20:53:49   Log-Likelihood:                -217.97
# No. Observations:                  51   AIC:                             507.9
# Df Residuals:                      15   BIC:                             577.5
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.629974e-19
# Origin_USA                    4.418741e-17
# Man.trans.avail_Yes           9.954195e-17
# AirBags_Driver only           3.656927e-16
# Origin_non-USA                4.958261e-15
# Man.trans.avail_No            2.824990e-14
# AirBags_None                  1.509018e-13
# DriveTrain_Rear               2.408749e-11
# DriveTrain_Front              3.224149e-10
# Horsepower                    1.388841e-09
# AirBags_Driver & Passenger    5.743223e-09
# MPG.highway                   1.171971e-08
# Rear.seat.room                2.193266e-08
# Manufacturer_BMW              1.457309e-06
# Luggage.room                  7.612118e-06
# Cylinders_4                   1.209918e-05
# Cylinders_6                   1.369865e-05
# Wheelbase                     1.770881e-05
# DriveTrain_4WD                3.003087e-05
# Fuel.tank.capacity            4.184722e-05
# Manufacturer_Mazda            4.508280e-05
# Manufacturer_Chrylser         1.096998e-04
# ...

# %%
Xnew=Xnew.drop(labels=["Type_Midsize"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     382.1
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           3.78e-18
# Time:                        20:53:49   Log-Likelihood:                -218.98
# No. Observations:                  51   AIC:                             508.0
# Df Residuals:                      16   BIC:                             575.6
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.210060e-20
# Origin_USA                    5.140245e-18
# Man.trans.avail_Yes           7.985214e-18
# AirBags_Driver only           2.550903e-17
# Origin_non-USA                7.597714e-16
# Man.trans.avail_No            2.047497e-15
# AirBags_None                  1.753775e-14
# DriveTrain_Rear               3.227506e-12
# DriveTrain_Front              2.464123e-11
# Horsepower                    4.698208e-11
# AirBags_Driver & Passenger    4.179040e-10
# MPG.highway                   4.071454e-09
# Rear.seat.room                9.295673e-09
# Manufacturer_BMW              2.233051e-07
# Luggage.room                  4.525374e-06
# Cylinders_4                   5.433644e-06
# Cylinders_6                   8.271559e-06
# Wheelbase                     9.891601e-06
# Fuel.tank.capacity            2.025003e-05
# DriveTrain_4WD                2.048026e-05
# Manufacturer_Mazda            3.396696e-05
# Length                        4.088263e-05
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Mercedes-Benz"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     395.9
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           2.88e-19
# Time:                        20:53:49   Log-Likelihood:                -220.38
# No. Observations:                  51   AIC:                             508.8
# Df Residuals:                      17   BIC:                             574.4
# Df Model:                          33
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.034680e-21
# Man.trans.avail_Yes           3.822497e-19
# Origin_USA                    5.556992e-19
# AirBags_Driver only           3.874102e-18
# Origin_non-USA                1.473776e-16
# Man.trans.avail_No            3.657087e-16
# AirBags_None                  3.058916e-15
# DriveTrain_Front              2.577867e-13
# DriveTrain_Rear               2.623750e-13
# Horsepower                    1.822368e-11
# AirBags_Driver & Passenger    7.215364e-11
# MPG.highway                   6.783011e-10
# Rear.seat.room                4.998632e-09
# Manufacturer_BMW              4.394206e-08
# Length                        4.935389e-07
# Cylinders_4                   2.294691e-06
# Luggage.room                  3.597806e-06
# Cylinders_6                   4.216828e-06
# Wheelbase                     8.164307e-06
# Fuel.tank.capacity            1.256590e-05
# DriveTrain_4WD                1.712667e-05
# Manufacturer_Mazda            2.130902e-05
# ...

# %%
Xnew=Xnew.drop(labels=["Max.Price"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     375.4
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           4.82e-20
# Time:                        20:53:49   Log-Likelihood:                -223.98
# No. Observations:                  51   AIC:                             514.0
# Df Residuals:                      18   BIC:                             577.7
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.604002e-22
# Man.trans.avail_Yes           9.192224e-20
# Origin_USA                    1.776314e-19
# AirBags_Driver only           2.824515e-19
# Origin_non-USA                3.250823e-17
# Man.trans.avail_No            4.022905e-17
# AirBags_None                  1.291508e-15
# DriveTrain_Rear               1.673180e-14
# DriveTrain_Front              4.936447e-14
# Horsepower                    1.623991e-11
# AirBags_Driver & Passenger    6.991272e-11
# MPG.highway                   6.225576e-10
# Rear.seat.room                5.716418e-09
# Manufacturer_BMW              5.896914e-08
# Length                        4.149975e-07
# Cylinders_4                   3.165353e-06
# Luggage.room                  4.066992e-06
# Manufacturer_Mazda            7.896472e-06
# Cylinders_6                   7.911798e-06
# Wheelbase                     1.127735e-05
# Fuel.tank.capacity            1.941173e-05
# DriveTrain_4WD                3.445459e-05
# ...

# %%
Xnew=Xnew.drop(labels=["Price"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     389.2
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           3.73e-21
# Time:                        20:53:49   Log-Likelihood:                -225.24
# No. Observations:                  51   AIC:                             514.5
# Df Residuals:                      19   BIC:                             576.3
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.621364e-23
# Origin_USA                    4.095018e-21
# AirBags_Driver only           9.286532e-21
# Man.trans.avail_Yes           1.246971e-20
# Origin_non-USA                1.021459e-18
# Man.trans.avail_No            6.086709e-18
# AirBags_None                  1.948958e-16
# DriveTrain_Rear               3.421944e-15
# DriveTrain_Front              1.429233e-14
# Horsepower                    3.990101e-12
# AirBags_Driver & Passenger    2.202644e-11
# MPG.highway                   2.871443e-10
# Rear.seat.room                3.319275e-09
# Manufacturer_BMW              3.679822e-08
# Length                        3.128936e-07
# Cylinders_4                   2.674147e-06
# Luggage.room                  3.493594e-06
# Wheelbase                     3.960478e-06
# Cylinders_6                   4.661673e-06
# Manufacturer_Mazda            6.753075e-06
# Fuel.tank.capacity            1.731009e-05
# DriveTrain_4WD                2.647639e-05
# ...

# %%
Xnew=Xnew.drop(labels=["Manufacturer_Lincoln"],axis=1)
Y=A[["Weight"]]
from Wd8pm import backward_elim
q=backward_elim(Xnew,Y)
q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     400.0
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):           3.13e-22
# Time:                        20:53:49   Log-Likelihood:                -226.69
# No. Observations:                  51   AIC:                             515.4
# Df Residuals:                      20   BIC:                             575.3
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
q.pvalues.sort_values()
# Out:
# const                         1.884437e-24
# Origin_USA                    5.541873e-22
# Man.trans.avail_Yes           1.285254e-21
# AirBags_Driver only           1.361529e-21
# Origin_non-USA                2.068290e-19
# Man.trans.avail_No            1.093100e-18
# AirBags_None                  5.458625e-17
# DriveTrain_Rear               7.459442e-16
# DriveTrain_Front              4.505390e-15
# Horsepower                    1.033897e-12
# AirBags_Driver & Passenger    1.032083e-11
# MPG.highway                   1.684562e-10
# Rear.seat.room                2.175148e-09
# Manufacturer_BMW              2.448035e-08
# Length                        2.418494e-07
# Cylinders_4                   1.307565e-06
# Cylinders_6                   1.681118e-06
# Wheelbase                     3.282227e-06
# Luggage.room                  3.404896e-06
# Manufacturer_Mazda            5.015616e-06
# DriveTrain_4WD                1.192723e-05
# Fuel.tank.capacity            1.773179e-05
# ...

# %% [markdown]
# # Final columns ,adj R2 reducing from next so stop here

# %%
Xnew.columns
# Out:
# Index(['MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'Rev.per.mile',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase',
#        'Rear.seat.room', 'Luggage.room', 'Manufacturer_Audi',
#        'Manufacturer_BMW', 'Manufacturer_Buick', 'Manufacturer_Cadillac',
#        'Manufacturer_Chevrolet', 'Manufacturer_Chrylser',
#        'Manufacturer_Chrysler', 'Manufacturer_Eagle', 'Manufacturer_Hyundai',
#        'Manufacturer_Mazda', 'Type_Van', 'AirBags_Driver & Passenger',
#        'AirBags_Driver only', 'AirBags_None', 'DriveTrain_4WD',
#        'DriveTrain_Front', 'DriveTrain_Rear', 'Cylinders_4', 'Cylinders_6',
#        'Man.trans.avail_No', 'Man.trans.avail_Yes', 'Origin_USA',
#        'Origin_non-USA'],
#       dtype='object')

# %% [markdown]
# # Take testing data

# %%
B=pd.read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/test.csv")

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  23 non-null     int64
#  1   Manufacturer        23 non-null     object
#  2   Model               23 non-null     object
#  3   Type                23 non-null     object
#  4   Min.Price           23 non-null     float64
#  5   Price               23 non-null     float64
#  6   Max.Price           23 non-null     float64
#  7   MPG.city            23 non-null     int64
#  8   MPG.highway         23 non-null     int64
#  9   AirBags             23 non-null     object
#  10  DriveTrain          23 non-null     object
#  11  Cylinders           23 non-null     int64
#  12  EngineSize          23 non-null     float64
#  13  Horsepower          23 non-null     int64
#  14  RPM                 23 non-null     int64
# ...

# %%
from Wd8pm import replacer
replacer(B)

# %%
from Wd8pm import OL
q = OL(B)

# %%
B = B.drop(index=q,axis=0)

# %%
B.shape
# Out:
# (23, 27)

# %%
B.index = range(0,23)

# %%
B
# Out:
#     id Manufacturer         Model     Type  Min.Price  Price  Max.Price  \
# 0   71   Oldsmobile  Eighty-Eight    Large       19.5   20.7       21.9
# 1   72     Plymouth         Laser   Sporty       11.4   14.4       17.4
# 2   73      Pontiac        LeMans    Small        8.2    9.0        9.9
# 3   74      Pontiac       Sunbird  Compact        9.4   11.1       12.8
# 4   75      Pontiac      Firebird   Sporty       14.0   17.7       21.4
# 5   76      Pontiac    Grand_Prix  Midsize       15.4   18.5       21.6
# 6   77      Pontiac    Bonneville    Large       19.4   24.4       29.4
# 7   78         Saab           900  Compact       20.3   28.7       37.1
# 8   79       Saturn            SL    Small        9.2   11.1       12.9
# 9   80       Subaru         Justy    Small        7.3    8.4        9.5
# 10  81       Subaru        Loyale    Small       10.5   10.9       11.3
# 11  82       Subaru        Legacy  Compact       16.3   19.5       22.7
# ...

# %% [markdown]
# # Training predictors

# %%
Y = A[["Weight"]]
X = Xnew[['MPG.city', 'MPG.highway', 'Horsepower', 'Rev.per.mile',
       'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase',
       'Rear.seat.room', 'Luggage.room', 'Manufacturer_Audi',
       'Manufacturer_BMW', 'Manufacturer_Buick', 'Manufacturer_Cadillac',
       'Manufacturer_Chevrolet', 'Manufacturer_Chrylser',
       'Manufacturer_Chrysler', 'Manufacturer_Eagle', 'Manufacturer_Hyundai',
       'Manufacturer_Mazda', 'Type_Van', 'AirBags_Driver & Passenger',
       'AirBags_Driver only', 'AirBags_None', 'DriveTrain_4WD',
       'DriveTrain_Front', 'DriveTrain_Rear', 'Cylinders_4', 'Cylinders_6',
       'Man.trans.avail_No', 'Man.trans.avail_Yes', 'Origin_USA',
       'Origin_non-USA']]

# %% [markdown]
# # create model

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

model = lm.fit(X,Y)
tr_pred = model.predict(X)

# %%
cat = []
con = []
for i in B.columns:
    if(B[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
B1 = pd.DataFrame(ss.fit_transform(B[con]),columns=con)
B2=pd.get_dummies(B[cat])
Bnew=B1.join(B2)

# %%
Bnew.shape
# Out:
# (23, 91)

# %% [markdown]
# # Take only predicted columns from standardised Bnew

# %%
Bnew1 = Bnew[['MPG.city', 'MPG.highway', 'Horsepower', 'Rev.per.mile',
       'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase',
       'Rear.seat.room', 'Luggage.room', 'Manufacturer_Audi',
       'Manufacturer_BMW', 'Manufacturer_Buick', 'Manufacturer_Cadillac',
       'Manufacturer_Chevrolet', 'Manufacturer_Chrylser',
       'Manufacturer_Chrysler', 'Manufacturer_Eagle', 'Manufacturer_Hyundai',
       'Manufacturer_Mazda', 'Type_Van', 'AirBags_Driver & Passenger',
       'AirBags_Driver only', 'AirBags_None', 'DriveTrain_4WD',
       'DriveTrain_Front', 'DriveTrain_Rear', 'Cylinders_4', 'Cylinders_6',
       'Man.trans.avail_No', 'Man.trans.avail_Yes', 'Origin_USA',
       'Origin_non-USA']]

# %% [markdown]
# # if error add missing columns to Bnew and find Bnew1 again

# %% [raw]
# ['Manufacturer_Audi', 'Manufacturer_BMW', 'Manufacturer_Buick', 'Manufacturer_Cadillac', 'Manufacturer_Chevrolet', 'Manufacturer_Chrylser', 'Manufacturer_Chrysler', 'Manufacturer_Eagle', 'Manufacturer_Hyundai', 'Manufacturer_Mazda', 'Cylinders_4', 'Cylinders_6']

# %%
Bnew["Manufacturer_Audi"]=0

# %%
Bnew["Manufacturer_BMW"]=0

# %%
Bnew["Manufacturer_Buick"]=0

# %%
Bnew["Manufacturer_Cadillac"]=0

# %%
Bnew["Manufacturer_Chevrolet"]=0

# %%
Bnew["Manufacturer_Chrylser"]=0

# %%
Bnew["Manufacturer_Chrysler"]=0

# %%
Bnew["Manufacturer_Eagle"]=0

# %%
Bnew["Manufacturer_Hyundai"]=0

# %%
Bnew["Manufacturer_Mazda"]=0

# %%
Bnew["Cylinders_4"]=0

# %%
Bnew["Cylinders_6"]=0

# %% [markdown]
# # find training error

# %%
from sklearn.metrics import mean_absolute_error
tr_err = mean_absolute_error(Y,tr_pred)

# %%
tr_err
# Out:
# 67.46192082493972

# %% [markdown]
# # prediction using Bnew1

# %%
Bnew1.shape
# Out:
# (23, 33)

# %%
X.shape
# Out:
# (64, 33)

# %%
ts_pred = model.predict(Bnew1)

# %%
ts_pred
# Out:
# array([[3854.02347724],
#        [2534.99017486],
#        [2466.46004153],
#        [2939.36634369],
#        [3477.30531864],
#        [3740.35701901],
#        [3570.59359084],
#        [3332.19899428],
#        [2682.18039226],
#        [2001.49011997],
#        [2738.23187714],
#        [3170.90255087],
#        [1996.07099918],
#        [2456.75018004],
#        [3073.42738897],
#        [3329.24087707],
#        [3811.33900324],
#        [2355.13829348],
#        [3662.57064311],
#        [3045.02891331],
#        [3118.74608854],
#        [3311.46158718],
#        [3438.32572324]])

# %%
Bnew["Weight"]=ts_pred

# %%
Bnew["Weight"]
# Out:
# 0     3854.023477
# 1     2534.990175
# 2     2466.460042
# 3     2939.366344
# 4     3477.305319
# 5     3740.357019
# 6     3570.593591
# 7     3332.198994
# 8     2682.180392
# 9     2001.490120
# 10    2738.231877
# 11    3170.902551
# 12    1996.070999
# 13    2456.750180
# 14    3073.427389
# 15    3329.240877
# 16    3811.339003
# 17    2355.138293
# 18    3662.570643
# 19    3045.028913
# 20    3118.746089
# 21    3311.461587
# 22    3438.325723
# Name: Weight, dtype: float64

# %%
Bnew
