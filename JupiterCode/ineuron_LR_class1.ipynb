# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset= fetch_california_housing()

# %%
dataset
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block group\n        - HouseAge      median house age in block group\n        - AveRooms      average number of rooms per household\n        - AveBedrms     average number of bedrooms per household\n        - Population    block group population\n        - AveOccup      average number of household members\n        - Latitude      block group latitude\n        - Longitude     block group longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nAn household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surpinsingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. topic:: References\n\n    - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n      Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
dataset.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
print(dataset.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
import pandas as pd

# %%
df=pd.DataFrame(dataset.data,columns=dataset.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
import seaborn as sb

# %%
df_copy=df.sample(frac=0.25)

# %%
sb.pairplot(df_copy)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude
# 5088   0.9809      19.0  3.187726   1.129964       726.0  2.620939     33.98
# 17096  4.2232      33.0  6.189696   1.086651      1015.0  2.377049     37.46
# 5617   3.5488      42.0  4.821577   1.095436      1044.0  4.331950     33.79
# 20060  1.6469      24.0  4.274194   1.048387      1686.0  4.532258     35.87
# 895    3.9909      14.0  4.608303   1.089350      2738.0  2.471119     37.54
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
# [13828 rows x 7 columns]

# %%
x.shape
# Out:
# (20640, 7)

# %%
x_train.shape
# Out:
# (13828, 7)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train= scaler.transform(x_train)

# %%
x_train
# Out:
# array([[-1.52169954, -0.75868455, -0.91813082, ..., -0.61496167,
#         -0.04014979, -0.78315293],
#        [ 0.18205382,  0.3523991 ,  0.30748451, ..., -0.36282305,
#         -0.05943619,  0.8475975 ],
#        [-0.17232772,  1.06666717, -0.25107784, ..., -0.33752194,
#          0.09515433, -0.87218816],
#        ...,
#        [-0.49518065,  0.59048846, -0.59192622, ...,  0.28366387,
#          0.01608523, -0.75972261],
#        [ 0.96816708, -1.07613702,  0.39144665, ...,  0.30198536,
#          0.0039722 ,  0.90383028],
#        [-0.68377427,  1.86029835, -0.83041358, ...,  1.03658993,
#         -0.08065717,  0.9928655 ]])

# %%
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([-0.38031225, -0.20703565,  0.47298424, -0.27332778, -0.05532736,
#         0.02850142, -1.91798124])

# %%
regression.intercept_
# Out:
# -119.58509835117154

# %%
y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([-269.76452571, -278.61032508, -275.05724432, ..., -340.82912301,
#        -381.16441765, -250.72108596])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
mae,mse
# Out:
# (151.65990070158531, 26619.157996857877)

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_pred,y_test)

# %%
#display adjusted R-squared
1 - (1-score)*(len(y)-1)/(len(y)-x.shape[1]-1)
# Out:
# -6.394025985287554

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=20.0)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=20.0)

# %%
y_pred=ridge.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
mae,mse
# Out:
# (151.03559821425503, 26381.62840757023)

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=20.0)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=20.0)

# %%
import numpy as np
y_pred=lasso.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 4.001873096350125
# 1.8284148980062243
# 2.0004682192802075

# %%
from sklearn.linear_model import ElasticNet
elastic=ElasticNet()
elastic.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred=elastic.predict(x_test)

# %%
import numpy as np
y_pred=lasso.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 4.001873096350125
# 1.8284148980062243
# 2.0004682192802075

# %%
df_copy.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.140809  0.327989  -0.075600    0.019582 -0.037007
# HouseAge   -0.140809  1.000000 -0.187610  -0.100464   -0.299378  0.016126
# AveRooms    0.327989 -0.187610  1.000000   0.841425   -0.087876 -0.062367
# AveBedrms  -0.075600 -0.100464  0.841425   1.000000   -0.086859 -0.072660
# Population  0.019582 -0.299378 -0.087876  -0.086859    1.000000  0.125032
# AveOccup   -0.037007  0.016126 -0.062367  -0.072660    0.125032  1.000000
# Latitude   -0.080746  0.002422  0.129874   0.092769   -0.108437 -0.111030
# Longitude  -0.016185 -0.103393 -0.024551   0.019665    0.089896  0.115876
#
#             Latitude  Longitude
# MedInc     -0.080746  -0.016185
# HouseAge    0.002422  -0.103393
# AveRooms    0.129874  -0.024551
# AveBedrms   0.092769   0.019665
# Population -0.108437   0.089896
# AveOccup   -0.111030   0.115876
# Latitude    1.000000  -0.919472
# Longitude  -0.919472   1.000000
