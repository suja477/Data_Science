# %%
from warnings import filterwarnings

# %%
filterwarnings("ignore")

# %%
import pandas as pd

# %%
A=pd.read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/Cars93.csv")

# %% [markdown]
# # Missing data treatment

# %%
from Wd8pm import replacer
replacer(A)

# %% [markdown]
# # Outliers

# %%
from Wd8pm import OL
q = OL(A)

# %%
A = A.drop(index=q,axis=0)

# %%
A.shape
# Out:
# (87, 28)

# %%
A.index = range(0,87)

# %% [markdown]
# # EDA
# X,Y,Preprocessing

# %%
X = A.drop(labels=["id","Make","Model","Weight"],axis=1)
Y = A[["Weight"]]

# %%
cat = []
con = []
for i in X.columns:
    if(X[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X1 = pd.DataFrame(ss.fit_transform(X[con]),columns=con)
X2=pd.get_dummies(X[cat])
Xnew=X1.join(X2)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

# %%
from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:32:13   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
ol.pvalues.sort_values()
# Out:
# const                      9.827775e-09
# Origin_non-USA             1.500918e-05
# Man.trans.avail_No         1.505594e-05
# Origin_USA                 3.819043e-05
# Man.trans.avail_Yes        1.044926e-04
#                                ...
# Manufacturer_Mitsubishi    8.279048e-01
# Type_Large                 8.392288e-01
# Cylinders_8                8.422048e-01
# Manufacturer_Volkswagen    8.527801e-01
# Manufacturer_Chevrolet     8.921655e-01
# Length: 71, dtype: float64

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
col_to_drop
# Out:
# 'Manufacturer_Chevrolet'

# %% [markdown]
# # model2

# %%
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:24:31   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # model3

# %%
col_to_drop
# Out:
# 'Manufacturer_Chevrolet'

# %%
Xold=Xnew
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:24:46   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # model4

# %%
col_to_drop
# Out:
# 'Manufacturer_Ford'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:22:28   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
no cnahge ,so add Xold=Xnew

# %%
Xnew=Xold

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:26:45   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop
# Out:
# 'Manufacturer_Ford'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:27:58   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold

# %%
col_to_drop
# Out:
# 'Manufacturer_Volkswagen'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:28:37   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold

# %%
col_to_drop
# Out:
# 'Manufacturer_Hyundai'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:29:01   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold

# %%
col_to_drop
# Out:
# 'Manufacturer_Volkswagen'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:29:24   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold
col_to_drop
# Out:
# 'Manufacturer_Hyundai'

# %%
Xnew=Xold
col_to_drop
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:29:51   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold
col_to_drop
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:30:07   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold
col_to_drop
# Out:
# 'Manufacturer_Volkswagen'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.71e-05
# Time:                        20:30:31   Log-Likelihood:                -336.78
# No. Observations:                  69   AIC:                             797.6
# Df Residuals:                       7   BIC:                             936.1
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
Xnew=Xold
col_to_drop
# Out:
# 'Manufacturer_Hyundai'

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:33:08   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:33:13   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     37.53
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           5.92e-06
# Time:                        20:33:20   Log-Likelihood:                -336.92
# No. Observations:                  69   AIC:                             795.8
# Df Residuals:                       8   BIC:                             932.1
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     42.92
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           8.75e-07
# Time:                        20:33:24   Log-Likelihood:                -336.94
# No. Observations:                  69   AIC:                             793.9
# Df Residuals:                       9   BIC:                             927.9
# Df Model:                          59
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     48.50
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           1.22e-07
# Time:                        20:33:30   Log-Likelihood:                -336.95
# No. Observations:                  69   AIC:                             791.9
# Df Residuals:                      10   BIC:                             923.7
# Df Model:                          58
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     53.88
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           1.67e-08
# Time:                        20:33:36   Log-Likelihood:                -337.21
# No. Observations:                  69   AIC:                             790.4
# Df Residuals:                      11   BIC:                             920.0
# Df Model:                          57
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     59.72
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           2.13e-09
# Time:                        20:33:42   Log-Likelihood:                -337.27
# No. Observations:                  69   AIC:                             788.5
# Df Residuals:                      12   BIC:                             915.9
# Df Model:                          56
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     65.18
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           2.74e-10
# Time:                        20:33:49   Log-Likelihood:                -337.63
# No. Observations:                  69   AIC:                             787.3
# Df Residuals:                      13   BIC:                             912.4
# Df Model:                          55
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     69.83
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.72e-11
# Time:                        20:33:55   Log-Likelihood:                -338.44
# No. Observations:                  69   AIC:                             786.9
# Df Residuals:                      14   BIC:                             909.8
# Df Model:                          54
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     69.83
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           3.72e-11
# Time:                        20:34:00   Log-Likelihood:                -338.44
# No. Observations:                  69   AIC:                             786.9
# Df Residuals:                      14   BIC:                             909.8
# Df Model:                          54
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop = ol.pvalues.sort_values().index[-1]
Xnew = Xnew.drop(labels=col_to_drop,axis=1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)

from statsmodels.api import add_constant
xconst = add_constant(xtrain)
from statsmodels.api import OLS
ol = OLS(ytrain,xconst).fit()
ol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     76.22
# Date:                Thu, 22 Sep 2022   Prob (F-statistic):           4.17e-12
# Time:                        20:34:04   Log-Likelihood:                -338.45
# No. Observations:                  69   AIC:                             784.9
# Df Residuals:                      15   BIC:                             905.5
# Df Model:                          53
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
col_to_drop
# Out:
# 'Cylinders_6'
