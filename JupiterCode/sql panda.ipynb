# %%
import pandas as pd
A=pd.read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/Credit.csv")
from warnings import filterwarnings 
filterwarnings("ignore")

# %%
from pandasql import sqldf
sqldf("select * from A")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             2    2  106.025   6645     483      3   82         15  Female
# 2             3    3  104.593   7075     514      4   71         11    Male
# 3             4    4  148.924   9504     681      3   36         11  Female
# 4             5    5   55.882   4897     357      2   68         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         396  396   12.096   4100     307      3   32         13    Male
# 396         397  397   13.364   3838     296      5   65         17    Male
# 397         398  398   57.872   4171     321      5   67         12  Female
# 398         399  399   37.728   2525     192      1   44         13    Male
# 399         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# ...

# %%
pip install pandasql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sqldf("select Age,Gender,Income,Student from A")
# Out:
#      Age  Gender   Income Student
# 0     34    Male   14.891      No
# 1     82  Female  106.025     Yes
# 2     71    Male  104.593      No
# 3     36  Female  148.924      No
# 4     68    Male   55.882      No
# ..   ...     ...      ...     ...
# 395   32    Male   12.096      No
# 396   65    Male   13.364      No
# 397   67  Female   57.872      No
# 398   44    Male   37.728      No
# 399   64  Female   18.701      No
#
# [400 rows x 4 columns]

# %%
sqldf("select * from A where Age > 85")
# Out:
#    Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           8    8   71.408   7114     512      2   87          9    Male
# 1         129  129  123.299   8376     610      2   89         17    Male
# 2         140  140  107.841  10384     728      3   87          7    Male
# 3         210  210  151.947   9156     642      2   91         11  Female
# 4         267  267   88.830   4952     360      4   86         16  Female
# 5         324  324  182.728  13913     982      4   98         17    Male
#
#   Student Married         Ethnicity  Balance
# 0      No      No             Asian      872
# 1     Yes      No  African American     1259
# 2      No      No  African American     1597
# 3      No     Yes  African American      732
# 4      No     Yes         Caucasian       15
# 5      No     Yes         Caucasian     1999

# %%
sqldf("select * from A where Age > 85 and Education > 10")
# Out:
#    Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0         129  129  123.299   8376     610      2   89         17    Male
# 1         210  210  151.947   9156     642      2   91         11  Female
# 2         267  267   88.830   4952     360      4   86         16  Female
# 3         324  324  182.728  13913     982      4   98         17    Male
#
#   Student Married         Ethnicity  Balance
# 0     Yes      No  African American     1259
# 1      No     Yes  African American      732
# 2      No     Yes         Caucasian       15
# 3      No     Yes         Caucasian     1999

# %%
sqldf("select * from A where Age > 85 or Education > 16")
# Out:
#     Unnamed: 0   ID  Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            8    8  71.408   7114     512      2   87          9    Male
# 1           10   10  71.061   6819     491      3   41         19  Female
# 2           17   17  53.598   3714     286      3   73         17  Female
# 3           22   22  37.348   6378     458      1   72         17  Female
# 4           52   52  39.705   3969     301      2   27         20    Male
# ..         ...  ...     ...    ...     ...    ...  ...        ...     ...
# 67         363  363  26.162   5101     382      3   62         19  Female
# 68         375  375  29.400   4840     368      3   76         18  Female
# 69         379  379  19.349   4941     366      1   33         19    Male
# 70         390  390  83.948   7100     503      2   44         18    Male
# 71         397  397  13.364   3838     296      5   65         17    Male
#
#    Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select * from A where Age > 35 and Student = 'Yes'")
# Out:
#     Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            2    2  106.025   6645     483      3   82         15  Female
# 1           10   10   71.061   6819     491      3   41         19  Female
# 2           27   27   42.471   3625     289      6   44         12  Female
# 3           36   36   23.350   2558     220      3   49         12  Female
# 4           42   42  113.659   7659     538      2   66         15    Male
# 5           47   47   19.531   5043     376      2   64         16  Female
# 6           48   48   44.646   4431     320      2   49         15    Male
# 7           50   50   43.479   4569     354      4   49         13    Male
# 8           77   77   30.622   3293     251      1   68         16    Male
# 9           97   97   14.312   5382     367      1   59         17    Male
# 10          99   99   36.295   2963     241      2   68         14  Female
# ...

# %%
sqldf("select * from A order by Age")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           336  336   24.314   3409     270      2   23          7  Female
# 1            44   44   36.929   6257     445      1   24         14  Female
# 2           153  153   41.419   2120     184      4   24         11  Female
# 3           393  393   25.974   2308     196      2   24         10    Male
# 4            26   26   14.090   4323     326      5   25         16  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395           8    8   71.408   7114     512      2   87          9    Male
# 396         140  140  107.841  10384     728      3   87          7    Male
# 397         129  129  123.299   8376     610      2   89         17    Male
# 398         210  210  151.947   9156     642      2   91         11  Female
# 399         324  324  182.728  13913     982      4   98         17    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select * from A order by Age desc")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           324  324  182.728  13913     982      4   98         17    Male
# 1           210  210  151.947   9156     642      2   91         11  Female
# 2           129  129  123.299   8376     610      2   89         17    Male
# 3             8    8   71.408   7114     512      2   87          9    Male
# 4           140  140  107.841  10384     728      3   87          7    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         273  273   30.413   3690     299      2   25         15  Female
# 396          44   44   36.929   6257     445      1   24         14  Female
# 397         153  153   41.419   2120     184      4   24         11  Female
# 398         393  393   25.974   2308     196      2   24         10    Male
# 399         336  336   24.314   3409     270      2   23          7  Female
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select AVG(Income) from A")
# Out:
#    AVG(Income)
# 0    45.218885

# %%
sqldf("select AVG(Income) as meanIncome from A")
# Out:
#    meanIncome
# 0   45.218885

# %%
sqldf("select Gender,AVG(Income) from A group by Gender")
# Out:
#    Gender  AVG(Income)
# 0    Male    45.610316
# 1  Female    44.853928

# %%
sqldf("select * from A where Age > 35 and Student = 'Yes' limit 5")
# Out:
#    Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           2   2  106.025   6645     483      3   82         15  Female
# 1          10  10   71.061   6819     491      3   41         19  Female
# 2          27  27   42.471   3625     289      6   44         12  Female
# 3          36  36   23.350   2558     220      3   49         12  Female
# 4          42  42  113.659   7659     538      2   66         15    Male
#
#   Student Married         Ethnicity  Balance
# 0     Yes     Yes             Asian      903
# 1     Yes     Yes  African American     1350
# 2     Yes      No         Caucasian      654
# 3     Yes      No         Caucasian      419
# 4     Yes     Yes  African American     1155

# %%
sqldf("select `limit` from A")
# Out:
#      Limit
# 0     3606
# 1     6645
# 2     7075
# 3     9504
# 4     4897
# ..     ...
# 395   4100
# 396   3838
# 397   4171
# 398   2525
# 399   5524
#
# [400 rows x 1 columns]

# %%
sqldf("select AVG(Income) from A")
# Out:
#    AVG(Income)
# 0    45.218885

# %%
sqldf("select AVG(Income) from A group by Gender")
# Out:
#    AVG(Income)
# 0    45.610316
# 1    44.853928

# %%
sqldf("select Gender,AVG(Income) from A group by Gender")
# Out:
#    Gender  AVG(Income)
# 0    Male    45.610316
# 1  Female    44.853928

# %%
from pandas import read_csv
emp = read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/emp_2.csv")
dept = read_csv("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset/dept.csv")

# %%
from pandas import merge

# %%
sqldf("select * from emp join dept on (emp.did = dept.dept_id)")
# Out:
#    empid      fn        ln    sal  did  dept_id dname
# 0    101   Naman     Singh   5000   20       20   MKT
# 1    102   Raman  Tripathi   7000   20       20   MKT
# 2    103  Chaman     Nagor   8000   20       20   MKT
# 3    104   Nisha     Patil   9000   30       30   SAL
# 4    105   Madhu     Reddy  10000   30       30   SAL

# %%
#merge(emp,dept,left_on="did",right_on="dept_id",how="left")
sqldf("select * from emp left outer join dept on (emp.did = dept.dept_id)")
# Out:
#    empid      fn        ln     sal  did  dept_id dname
# 0    101   Naman     Singh    5000   20     20.0   MKT
# 1    102   Raman  Tripathi    7000   20     20.0   MKT
# 2    103  Chaman     Nagor    8000   20     20.0   MKT
# 3    104   Nisha     Patil    9000   30     30.0   SAL
# 4    105   Madhu     Reddy   10000   30     30.0   SAL
# 5    106   Rahul   Barkade  122746  113      NaN  None

# %%
A1 = A[0:10]
A2 = A[10:20]

#pd.concat([A1,A2])
sqldf("select * from A1 union select * from A2")
# Out:
#     Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            1   1   14.891   3606     283      2   34         11    Male
# 1            2   2  106.025   6645     483      3   82         15  Female
# 2            3   3  104.593   7075     514      4   71         11    Male
# 3            4   4  148.924   9504     681      3   36         11  Female
# 4            5   5   55.882   4897     357      2   68         16    Male
# 5            6   6   80.180   8047     569      4   77         10    Male
# 6            7   7   20.996   3388     259      2   37         12  Female
# 7            8   8   71.408   7114     512      2   87          9    Male
# 8            9   9   15.125   3300     266      5   66         13  Female
# 9           10  10   71.061   6819     491      3   41         19  Female
# 10          11  11   63.095   8117     589      4   30         14    Male
# 11          12  12   15.045   1311     138      3   64         16    Male
# ...

# %%
A["newIncome"]=A.Income*74

# %%
sqldf("select *,Income*74 as 'newIncomeINR' from A")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             2    2  106.025   6645     483      3   82         15  Female
# 2             3    3  104.593   7075     514      4   71         11    Male
# 3             4    4  148.924   9504     681      3   36         11  Female
# 4             5    5   55.882   4897     357      2   68         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         396  396   12.096   4100     307      3   32         13    Male
# 396         397  397   13.364   3838     296      5   65         17    Male
# 397         398  398   57.872   4171     321      5   67         12  Female
# 398         399  399   37.728   2525     192      1   44         13    Male
# 399         400  400   18.701   5524     415      5   64          7  Female
#
# ...
